# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/guinascim/ImpactofInternet_GlobalGDP/main/Dataset/Dataset%20Inicial/Media/social_media.csv'
media = pd.read_csv(url)

# %%
media.head()
# Out:
#       Date  Facebook  Pinterest  Twitter  StumbleUpon  YouTube  Instagram  \
# 0  2009-04     20.16        0.0     6.86        36.79      0.0        0.0
# 1  2009-05     24.30        0.0     9.95        33.78      0.0        0.0
# 2  2009-06     26.48        0.0    10.56        29.65      0.0        0.0
# 3  2009-07     29.10        0.0    10.35        33.55      0.0        0.0
# 4  2009-08     34.25        0.0    11.15        29.01      0.0        0.0
#
#    Tumblr  reddit  VKontakte  ...  MySpace  Fark  NowPublic  iWiW  \
# 0     0.0    8.98        0.0  ...    14.81  0.22       0.04  0.29
# 1     0.0    7.62        0.0  ...     8.95  0.44       0.05  2.10
# 2     0.0   12.13        0.0  ...     7.66  0.66       0.05  2.35
# 3     0.0    9.52        0.0  ...     5.49  0.22       0.03  2.21
# 4     0.0    9.37        0.0  ...     4.69  0.40       0.08  2.27
#
#    news.ycombinator.com  Delicious  orkut  Odnoklassniki  Vimeo  Other
# ...

# %%
media['Date'] = pd.to_datetime(media['Date'])
media['Year'] = media['Date'].dt.year

# %%
media.drop(columns=['Date'], inplace=True)
media = media[['Year'] + [col for col in media if col != 'Year']]

# %%
media.head()
# Out:
#    Year  Facebook  Pinterest  Twitter  StumbleUpon  YouTube  Instagram  \
# 0  2009     20.16        0.0     6.86        36.79      0.0        0.0
# 1  2009     24.30        0.0     9.95        33.78      0.0        0.0
# 2  2009     26.48        0.0    10.56        29.65      0.0        0.0
# 3  2009     29.10        0.0    10.35        33.55      0.0        0.0
# 4  2009     34.25        0.0    11.15        29.01      0.0        0.0
#
#    Tumblr  reddit  VKontakte  ...  MySpace  Fark  NowPublic  iWiW  \
# 0     0.0    8.98        0.0  ...    14.81  0.22       0.04  0.29
# 1     0.0    7.62        0.0  ...     8.95  0.44       0.05  2.10
# 2     0.0   12.13        0.0  ...     7.66  0.66       0.05  2.35
# 3     0.0    9.52        0.0  ...     5.49  0.22       0.03  2.21
# 4     0.0    9.37        0.0  ...     4.69  0.40       0.08  2.27
#
#    news.ycombinator.com  Delicious  orkut  Odnoklassniki  Vimeo  Other
# ...

# %%
media_grouped = media.groupby('Year').sum().reset_index()

# %%
media_grouped = media_grouped[(media_grouped['Year'] >= 2010) & (media_grouped['Year'] <= 2020)]
media_grouped.head()
# Out:
#    Year  Facebook  Pinterest  Twitter  StumbleUpon  YouTube  Instagram  \
# 1  2010    712.43       0.00    76.81       225.48    77.71        0.0
# 2  2011    785.19       0.00    54.20       248.86    63.82        0.0
# 3  2012    782.97      87.14    78.88       105.77    89.79        0.0
# 4  2013    794.52     134.36   118.08        51.68    36.75        0.0
# 5  2014    869.08     114.39    82.88        23.33    13.44        0.0
#
#    Tumblr  reddit  VKontakte  ...  MySpace  Fark  NowPublic  iWiW  \
# 1    0.00   39.41       0.00  ...    15.28  2.94       7.58  6.46
# 2    0.00   28.24       1.80  ...     0.59  1.53       2.62  0.49
# 3    0.00   38.77       4.17  ...     0.15  1.24       2.12  0.16
# 4   20.15   30.64       4.25  ...     0.05  0.98       0.98  0.01
# 5   67.55   21.63       2.37  ...     0.00  0.36       0.00  0.00
#
#    news.ycombinator.com  Delicious  orkut  Odnoklassniki  Vimeo  Other
# ...

# %%
media_grouped.shape
# Out:
# (11, 24)

# %%
transposed_df = media_grouped.T.reset_index()
transposed_df.columns = transposed_df.iloc[0]
transposed_df = transposed_df.drop(0)
transposed_df.reset_index(drop=True, inplace=True)
transposed_df = transposed_df.rename(columns={'Year': 'Media'})
transposed_df.head()
# Out:
# 0        Media  2010.0  2011.0  2012.0  2013.0  2014.0   2015.0   2016.0  \
# 0     Facebook  712.43  785.19  782.97  794.52  869.08  1001.15  1033.70
# 1    Pinterest    0.00    0.00   87.14  134.36  114.39    79.41    73.37
# 2      Twitter   76.81   54.20   78.88  118.08   82.88    63.83    51.12
# 3  StumbleUpon  225.48  248.86  105.77   51.68   23.33    10.15     5.16
# 4      YouTube   77.71   63.82   89.79   36.75   13.44     1.40     3.07
#
# 0  2017.0  2018.0  2019.0  2020.0
# 0  994.50  814.03  829.79  827.44
# 1   91.35  159.43  167.72  139.32
# 2   57.91   88.19   96.63  122.07
# 3    3.16    1.81    0.04    0.00
# 4   20.24   85.95   46.34   49.54

# %%
transposed_df.columns = transposed_df.columns.astype(str).str.split('.').str[0]

# %%
transposed_df.columns
# Out:
# Index(['Media', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020'],
#       dtype='object', name=0)

# %%
transposed_df.head()
# Out:
# 0        Media    2010    2011    2012    2013    2014     2015     2016  \
# 0     Facebook  712.43  785.19  782.97  794.52  869.08  1001.15  1033.70
# 1    Pinterest    0.00    0.00   87.14  134.36  114.39    79.41    73.37
# 2      Twitter   76.81   54.20   78.88  118.08   82.88    63.83    51.12
# 3  StumbleUpon  225.48  248.86  105.77   51.68   23.33    10.15     5.16
# 4      YouTube   77.71   63.82   89.79   36.75   13.44     1.40     3.07
#
# 0    2017    2018    2019    2020
# 0  994.50  814.03  829.79  827.44
# 1   91.35  159.43  167.72  139.32
# 2   57.91   88.19   96.63  122.07
# 3    3.16    1.81    0.04    0.00
# 4   20.24   85.95   46.34   49.54

# %%
transposed_df.to_csv('me_popular.csv', index=False)
