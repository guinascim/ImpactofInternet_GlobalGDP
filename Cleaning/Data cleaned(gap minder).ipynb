# %%
import pandas as pd

Countries = pd.read_csv(r"C:\Users\joaop\Desktop\Final_Project (1)-20240306T153358Z-001\Final_Project (1)\List of Countries by number of Internet Users - Sheet1.csv")

# %%
Countries
# Out:
#                       Country or Area Internet Users     Population  Rank  \
# 0                               China    765,367,947  1,409,517,397     1
# 1                               India    461,347,554  1,339,180,127     2
# 2                       United States    244,090,854    324,459,463     3
# 3                              Brazil    141,206,801    209,288,278     4
# 4                               Japan    115,845,120    127,484,450     5
# 5                              Russia    109,446,612    143,989,754     6
# 6                           Indonesia     85,242,816    263,991,379     7
# 7                              Mexico     82,470,752    129,163,276     8
# 8                             Germany     69,304,405     82,114,224     9
# 9                         Philippines     63,003,313    104,918,090    10
# 10                     United Kingdom     62,621,016     66,181,585    11
# 11                           Pakistan     61,837,331    220,800,300    25
# ...

# %%
Countries_clean = Countries_clean.drop(columns=['Percentage'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 Countries_clean = Countries_clean.drop(columns=['Percentage'])
#
# File c:\Users\joaop\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
Countries_clean
# Out:
#        Country or Area Internet Users     Population
# 0                China    765,367,947  1,409,517,397
# 1                India    461,347,554  1,339,180,127
# 2        United States    244,090,854    324,459,463
# 3               Brazil    141,206,801    209,288,278
# 4                Japan    115,845,120    127,484,450
# ..                 ...            ...            ...
# 210   Falkland Islands          2,881          2,910
# 211         Montserrat          2,833          5,177
# 212  Wallis and Futuna          1,383         11,773
# 213               Niue          1,034          1,618
# 214          Ascension            361            806
#
# [215 rows x 3 columns]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
Countries_clean.rename(columns={'Country or Area': 'Country'}, inplace=True)

# %%
Countries_clean
# Out:
#                               Country Internet Users     Population
# 0                               China    765,367,947  1,409,517,397
# 1                               India    461,347,554  1,339,180,127
# 2                       United States    244,090,854    324,459,463
# 3                              Brazil    141,206,801    209,288,278
# 4                               Japan    115,845,120    127,484,450
# 5                              Russia    109,446,612    143,989,754
# 6                           Indonesia     85,242,816    263,991,379
# 7                              Mexico     82,470,752    129,163,276
# 8                             Germany     69,304,405     82,114,224
# 9                         Philippines     63,003,313    104,918,090
# 10                     United Kingdom     62,621,016     66,181,585
# 11                           Pakistan     61,837,331    220,800,300
# 12                             France     52,308,536     64,979,548
# ...
